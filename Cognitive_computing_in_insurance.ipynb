# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavirajput12/insurance/blob/main/Cognitive_computing_in_insurance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **HEALTH INSURANCE APPLICATION**

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/drive/MyDrive/insurance.csv")

# %%
data.head()
# Out:
#    Age  Gender     BMI  Children Existing illness Surgical procedure  \
# 0   19  female  27.900         0              yes                 no
# 1   18    male  33.770         1               no                 no
# 2   28    male  33.000         3               no                 no
# 3   33    male  22.705         0               no                 no
# 4   32    male  28.880         0               no                 no
#
#   Alcohol consumption Covid 19  Health Premium Cost
# 0                 yes       no          16884.92400
# 1                 yes       no           1725.55230
# 2                 yes       no           4449.46200
# 3                 yes       no          21984.47061
# 4                 yes       no           3866.85520

# %%
data.tail()
# Out:
#       Age  Gender    BMI  Children Existing illness Surgical procedure  \
# 1333   50    male  30.97         3               no                 no
# 1334   18  female  31.92         0               no                 no
# 1335   18  female  36.85         0               no                 no
# 1336   21  female  25.80         0               no                 no
# 1337   61  female  29.07         0              yes                 no
#
#      Alcohol consumption Covid 19  Health Premium Cost
# 1333                  no      yes           10600.5483
# 1334                 yes      yes            2205.9808
# 1335                 yes      yes            1629.8335
# 1336                 yes      yes            2007.9450
# 1337                 yes      yes           29141.3603

# %%
#find shape of our dataset
data.shape
# Out:
# (1338, 9)

# %%
print("no of rows:", data.shape[0])
print("no of columns:", data.shape[1])
# Out:
# no of rows: 1338
# no of columns: 9

# %%
#get information about dataset
data.info
# Out:
# <bound method DataFrame.info of       Age  Gender     BMI  Children Existing illness Surgical procedure  \
# 0      19  female  27.900         0              yes                 no
# 1      18    male  33.770         1               no                 no
# 2      28    male  33.000         3               no                 no
# 3      33    male  22.705         0               no                 no
# 4      32    male  28.880         0               no                 no
# ...   ...     ...     ...       ...              ...                ...
# 1333   50    male  30.970         3               no                 no
# 1334   18  female  31.920         0               no                 no
# 1335   18  female  36.850         0               no                 no
# 1336   21  female  25.800         0               no                 no
# 1337   61  female  29.070         0              yes                 no
#
#      Alcohol consumption Covid 19  Health Premium Cost
# ...

# %%
# to check null values
data.isnull()
# Out:
#         Age  Gender    BMI  Children  Existing illness  Surgical procedure  \
# 0     False   False  False     False             False               False
# 1     False   False  False     False             False               False
# 2     False   False  False     False             False               False
# 3     False   False  False     False             False               False
# 4     False   False  False     False             False               False
# ...     ...     ...    ...       ...               ...                 ...
# 1333  False   False  False     False             False               False
# 1334  False   False  False     False             False               False
# 1335  False   False  False     False             False               False
# 1336  False   False  False     False             False               False
# 1337  False   False  False     False             False               False
#
#       Alcohol consumption  Covid 19  Health Premium Cost
# ...

# %%
data.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# BMI                    0
# Children               0
# Existing illness       0
# Surgical procedure     0
# Alcohol consumption    0
# Covid 19               0
# Health Premium Cost    0
# dtype: int64

# %%
#get overall statistics about the dataset
data.describe(include="all")
# Out:
#                 Age Gender          BMI     Children Existing illness  \
# count   1338.000000   1338  1338.000000  1338.000000             1338
# unique          NaN      2          NaN          NaN                2
# top             NaN   male          NaN          NaN               no
# freq            NaN    676          NaN          NaN             1064
# mean      39.207025    NaN    30.663397     1.094918              NaN
# std       14.049960    NaN     6.098187     1.205493              NaN
# min       18.000000    NaN    15.960000     0.000000              NaN
# 25%       27.000000    NaN    26.296250     0.000000              NaN
# 50%       39.000000    NaN    30.400000     1.000000              NaN
# 75%       51.000000    NaN    34.693750     2.000000              NaN
# max       64.000000    NaN    53.130000     5.000000              NaN
#
#        Surgical procedure Alcohol consumption Covid 19  Health Premium Cost
# ...

# %%
data.head()
# Out:
#    Age  Gender     BMI  Children Existing illness Surgical procedure  \
# 0   19  female  27.900         0              yes                 no
# 1   18    male  33.770         1               no                 no
# 2   28    male  33.000         3               no                 no
# 3   33    male  22.705         0               no                 no
# 4   32    male  28.880         0               no                 no
#
#   Alcohol consumption Covid 19  Health Premium Cost
# 0                 yes       no          16884.92400
# 1                 yes       no           1725.55230
# 2                 yes       no           4449.46200
# 3                 yes       no          21984.47061
# 4                 yes       no           3866.85520

# %%
#convert columns from string to numerical values
data['Gender'].unique
# Out:
# <bound method Series.unique of 0       female
# 1         male
# 2         male
# 3         male
# 4         male
#          ...
# 1333      male
# 1334    female
# 1335    female
# 1336    female
# 1337    female
# Name: Gender, Length: 1338, dtype: object>

# %%
data['Gender']=data['Gender'].map({'female':0, 'male':1})
data.head()
# Out:
#    Age  Gender     BMI  Children Existing illness Surgical procedure  \
# 0   19       0  27.900         0              yes                 no
# 1   18       1  33.770         1               no                 no
# 2   28       1  33.000         3               no                 no
# 3   33       1  22.705         0               no                 no
# 4   32       1  28.880         0               no                 no
#
#   Alcohol consumption Covid 19  Health Premium Cost
# 0                 yes       no          16884.92400
# 1                 yes       no           1725.55230
# 2                 yes       no           4449.46200
# 3                 yes       no          21984.47061
# 4                 yes       no           3866.85520

# %%
data['Existing illness']=data['Existing illness'].map({'yes':1,'no':0})
data.head()
# Out:
#    Age  Gender     BMI  Children  Existing illness Surgical procedure  \
# 0   19       0  27.900         0                 1                 no
# 1   18       1  33.770         1                 0                 no
# 2   28       1  33.000         3                 0                 no
# 3   33       1  22.705         0                 0                 no
# 4   32       1  28.880         0                 0                 no
#
#   Alcohol consumption Covid 19  Health Premium Cost
# 0                 yes       no          16884.92400
# 1                 yes       no           1725.55230
# 2                 yes       no           4449.46200
# 3                 yes       no          21984.47061
# 4                 yes       no           3866.85520

# %%
data['Surgical procedure']=data['Surgical procedure'].map({'yes':1,'no':0})
data.head()
# Out:
#    Age  Gender     BMI  Children  Existing illness  Surgical procedure  \
# 0   19       0  27.900         0                 1                   0
# 1   18       1  33.770         1                 0                   0
# 2   28       1  33.000         3                 0                   0
# 3   33       1  22.705         0                 0                   0
# 4   32       1  28.880         0                 0                   0
#
#   Alcohol consumption Covid 19  Health Premium Cost
# 0                 yes       no          16884.92400
# 1                 yes       no           1725.55230
# 2                 yes       no           4449.46200
# 3                 yes       no          21984.47061
# 4                 yes       no           3866.85520

# %%
data['Alcohol consumption']=data['Alcohol consumption'].map({'yes':1,'no':0})
data.head()
# Out:
#    Age  Gender     BMI  Children  Existing illness  Surgical procedure  \
# 0   19       0  27.900         0                 1                   0
# 1   18       1  33.770         1                 0                   0
# 2   28       1  33.000         3                 0                   0
# 3   33       1  22.705         0                 0                   0
# 4   32       1  28.880         0                 0                   0
#
#    Alcohol consumption Covid 19  Health Premium Cost
# 0                    1       no          16884.92400
# 1                    1       no           1725.55230
# 2                    1       no           4449.46200
# 3                    1       no          21984.47061
# 4                    1       no           3866.85520

# %%
data['Covid 19']=data['Covid 19'].map({'yes':1,'no':0})
data.head()
# Out:
#    Age  Gender     BMI  Children  Existing illness  Surgical procedure  \
# 0   19       0  27.900         0                 1                   0
# 1   18       1  33.770         1                 0                   0
# 2   28       1  33.000         3                 0                   0
# 3   33       1  22.705         0                 0                   0
# 4   32       1  28.880         0                 0                   0
#
#    Alcohol consumption  Covid 19  Health Premium Cost
# 0                    1         0          16884.92400
# 1                    1         0           1725.55230
# 2                    1         0           4449.46200
# 3                    1         0          21984.47061
# 4                    1         0           3866.85520

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'BMI', 'Children', 'Existing illness',
#        'Surgical procedure', 'Alcohol consumption', 'Covid 19',
#        'Health Premium Cost'],
#       dtype='object')

# %%
#store feature matrix in X and response(target)in vector Y
x= data.drop(['Health Premium Cost'], axis=1)

# %%
y= data['Health Premium Cost']
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: Health Premium Cost, Length: 1338, dtype: float64

# %%
# 1. split data into two parts: training and testing set
# 2. train the model(s) on the training set
#3. test the model(s) on the Testing set

from sklearn.model_selection import train_test_split
x_train , x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
x_train
# Out:
#       Age  Gender     BMI  Children  Existing illness  Surgical procedure  \
# 560    46       0  19.950         2                 0                   1
# 1285   47       0  24.320         0                 0                   0
# 1142   52       0  24.860         0                 0                   1
# 969    39       0  34.320         5                 0                   0
# 486    54       0  21.470         3                 0                   1
# ...   ...     ...     ...       ...               ...                 ...
# 1095   18       0  31.350         4                 0                   0
# 1130   39       0  23.870         5                 0                   1
# 1294   58       1  25.175         0                 0                   0
# 860    37       0  47.600         2                 1                   1
# 1126   55       1  29.900         0                 0                   1
#
#       Alcohol consumption  Covid 19
# 560                     1         0
# ...

# %%
y_train
# Out:
# 560      9193.83850
# 1285     8534.67180
# 1142    27117.99378
# 969      8596.82780
# 486     12475.35130
#            ...
# 1095     4561.18850
# 1130     8582.30230
# 1294    11931.12525
# 860     46113.51100
# 1126    10214.63600
# Name: Health Premium Cost, Length: 1070, dtype: float64

# %%
#import models

from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
#model training 
lr = LinearRegression()
lr.fit(x_train,y_train)
svm= SVR()
svm.fit(x_train,y_train)
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
gr=GradientBoostingRegressor()
gr.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred1=lr.predict(x_test)
y_pred2=svm.predict(x_test)
y_pred3=rf.predict(x_test)
y_pred4=gr.predict(x_test)

df1 = pd.DataFrame({'Actual':y_test, 'Lr':y_pred1, 'svm':y_pred2 , 'rf':y_pred3, 'gr':y_pred4})
df1
# Out:
#            Actual            Lr          svm            rf            gr
# 764    9095.06825   8568.184849  9550.831680  11561.032746  10439.830888
# 887    5272.17580   6986.496486  9500.534344   5228.248857   6000.080317
# 890   29330.98315  36810.053376  9643.561212  28065.197704  28087.387080
# 1293   9301.89355   9738.990517  9556.979036   9325.901254   9804.243725
# 259   33750.29180  26809.036731  9432.205209  34477.593334  33914.083059
# ...           ...           ...          ...           ...           ...
# 109   47055.53210  39183.183850  9643.535205  47172.400233  45728.193623
# 575   12222.89830  11712.841785  9621.198401  12128.307109  12974.656144
# 535    6067.12675   7268.798433  9511.013943   5902.636808   6433.325944
# 543   63770.42801  40967.939605  9603.303277  46698.625194  48114.743060
# 846    9872.70100  12589.536958  9589.616516  10258.930944  10666.795603
#
# [268 rows x 5 columns]

# %%
#comapre performace visually

import matplotlib.pyplot as plt

# %%
plt.subplot(221)
plt.plot(df1['Actual'].iloc[0:11],label='Actual')
plt.plot(df1['Lr'].iloc[0:11],label="Lr")
plt.legend()

plt.subplot(222)
plt.plot(df1['Actual'].iloc[0:11],label='Actual')
plt.plot(df1['svm'].iloc[0:11],label="svm")
plt.legend()

plt.subplot(223)
plt.plot(df1['Actual'].iloc[0:11],label='Actual')
plt.plot(df1['rf'].iloc[0:11],label="rf")
plt.legend()

plt.subplot(224)
plt.plot(df1['Actual'].iloc[0:11],label='Actual')
plt.plot(df1['gr'].iloc[0:11],label="gr")

plt.tight_layout()
plt.legend()

# %%
from sklearn import metrics

# %%
score1 = metrics.r2_score(y_test, y_pred1)
score2 = metrics.r2_score(y_test, y_pred2)
score3 = metrics.r2_score(y_test, y_pred3)
score4 = metrics.r2_score(y_test, y_pred4)

print(score1,score2,score3,score4)
# Out:
# 0.7804872179173784 -0.07241871334749583 0.8581816667323177 0.8777626504044876

# %%
score1 = metrics.median_absolute_error(y_test, y_pred1)
score2 = metrics.median_absolute_error(y_test, y_pred2)
score3 = metrics.median_absolute_error(y_test, y_pred3)
score4 = metrics.median_absolute_error(y_test, y_pred4)

print(score1,score2,score3,score4)
# Out:
# 2740.5095991684557 5338.754597359515 1202.1293838000074 1478.0088964120218

# %%
score1 = metrics.mean_absolute_error(y_test, y_pred1)
score2 = metrics.mean_absolute_error(y_test, y_pred2)
score3 = metrics.mean_absolute_error(y_test, y_pred3)
score4 = metrics.mean_absolute_error(y_test, y_pred4)

print(score1,score2,score3,score4)
# Out:
# 4222.113163128139 8596.512729434484 2643.1086850906718 2434.4109820908575

# %%
#predict charges for new patients

data = {'Age': 40,
        'Gender': 1,
        'BMI': 26.7,
        'Children': 3,
        'Existing illness': 1,
        'Surgical procedure': 0,
        'Alcohol consumption': 1,
        'Covid 19': 1}

df = pd.DataFrame(data, index=[0])
df
# Out:
#    Age  Gender   BMI  Children  Existing illness  Surgical procedure  \
# 0   40       1  26.7         3                 1                   0
#
#    Alcohol consumption  Covid 19
# 0                    1         1

# %%
new_pred=gr.predict(df)
print(new_pred)
# Out:
# [21787.82941338]

# %%
gr = GradientBoostingRegressor()
gr.fit(x,y)
# Out:
# GradientBoostingRegressor()

# %%
import joblib
joblib.dump(gr, 'model_joblib_gr')
model = joblib.load('model_joblib_gr')
model.predict(df)
# Out:
# array([21612.22992953])

# %%
from tkinter import *
import joblib

def show_entry():
    
  p1 = float(e1.get())
  p2 = float(e2.get())
  p3 = float(e3.get())
  p4 = float(e4.get())
  p5 = float(e5.get())
  p6 = float(e6.get())
  p7 = float(e7.get())
  p8 = float(e8.get())
    
  model = joblib.load('model_joblib_gr')
  Result = model.predict([[p1,p2,p3,p4,p5,p6,p7,p8]])

  label_9 = Label(master, text="Predicted Insurance Cost",font=("bold", 12),bg="light green").place(x=50,y=380)

  label_10 = Label(master, text= Result,font=("bold", 12),bg="white").place(x=50,y=410)
    
   
  master = Tk()
  master.geometry('500x500')
  master.configure(bg="light yellow")
  master.title("Insurance Prediction Application")


  label_0 = Label(master, text="Health Insurance Prediction Application",font=("bold", 14),justify = "center", fg = "black").place(x=80,y=10)

  label_1 = Label(master, text="1. Enter Your Age:",font=("bold", 10),bg="light yellow").place(x=50,y=80)
  e1 = Entry(master)
  e1.place(x=340,y=80)

  label_2 = Label(master, text="2. Enter gender: Male Or Female [1/0]:",font=("bold", 10),bg="light yellow").place(x=50,y=110)
  e2 = Entry(master)
  e2.place(x=340,y=110)

  label_3 = Label(master, text="3. Enter your BMI Value:",font=("bold", 10),bg="light yellow").place(x=50,y=140)
  e3 = Entry(master)
  e3.place(x=340,y=140)

  label_4 = Label(master, text="4. Enter Number of Children:",font=("bold", 10),bg="light yellow").place(x=50,y=170)
  e4 = Entry(master)
  e4.place(x=340,y=170)

  label_5 = Label(master, text="5. Any Exiting illness Yes/No [1/0]:",font=("bold", 10),bg="light yellow").place(x=50,y=200)
  e5 = Entry(master)
  e5.place(x=340,y=200)

  label_6 = Label(master, text="6. Any Surgical procedure ongoing Yes/No [1/0]:",font=("bold", 10),bg="light yellow").place(x=50,y=230)
  e6 = Entry(master)
  e6.place(x=340,y=230)

  label_7 = Label(master, text="7. Alcohol consumption Yes/No [1/0]:",font=("bold", 10),bg="light yellow").place(x=50,y=260)
  e7 = Entry(master)
  e7.place(x=340,y=260)

  label_8 = Label(master, text="8. Covid 19 Yes/No [1/0]:",font=("bold", 10),bg="light yellow").place(x=50,y=290)
  e8 = Entry(master)
  e8.place(x=340,y=290)

  Button(master, text='Result',width=30,bg='black',fg='white', command = show_entry).place(x=130,y=350)

  master.mainloop()
